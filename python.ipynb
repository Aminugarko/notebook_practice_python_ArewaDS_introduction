# %%
print (2)
# Out:
# 2

# %%
print ( " im using   \n my name")
# Out:
#  im using
#  my name

# %%
print ("imusing  tnmy laptop")
# Out:
# imusing  tnmy laptop

# %%
print (" hello world" * 3 )
# Out:
#  hello world hello world hello world

# %%
print ("P + 10")
# Out:
# P + 10

# %%
title ="ArewaDs"
banna = ... #
banner = 
age = "25 "
print (" age is", age)
# Out:
#   Cell In[3], line 3
#     banner =
#              ^
# SyntaxError: invalid syntax

# %%
age = 25
print (" age is", age)
# Out:
#  age is 25

# %%
amount = 12000
vat = ... 
print (vat)
# Out:
# Ellipsis

# %%
vat_rate = 0.70
amuntcd = 250.0
amountUSD = amountcd*rate

# %%
hours = ...
minute = ...
seconds = ...
print ( hours "h" minute "m" second "s")
# Out:
#   Cell In[8], line 4
#     print ( hours "h" minute "m" second "s")
#                       ^
# SyntaxError: invalid syntax. Is this intended to be part of the string?

# %%
print ( round (-7), max(2,3,6), min(123))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print ( round (-7), max(2,3,6), min(123))
#
# TypeError: 'int' object is not iterable
